# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmeh-ctrl/python-codewars/blob/master/headlines_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
maplist=[]
with open('headlines.txt', 'r') as headlines:
    for line in headlines:
        maplist.append(line.rstrip('\n'))

# %%
for headline in maplist:
    print(headline)
# Out:
# Zika Outbreak Hits Miami
# Could Zika Reach New York City?
# First Case of Zika in Miami Beach
# Mystery Virus Spreads in Recife, Brazil
# Dallas man comes down with case of Zika
# Trinidad confirms first Zika case
# Zika Concerns are Spreading in Houston
# Geneve Scientists Battle to Find Cure
# The CDC in Atlanta is Growing Worried
# Zika Infested Monkeys in Sao Paulo
# Brownsville teen contracts Zika virus
# Mosquito control efforts in St. Louis take new tactics with Zika threat
# San Juan reports 1st U.S. Zika-related death amid outbreak
# Flu outbreak in Galveston, Texas
# Zika alert – Manila now threatened
# Zika afflicts 7 in Iloilo City
# New Los Angeles Hairstyle goes Viral
# Louisiana Zika cases up to 26
# Orlando volunteers aid Zika research
# Zika infects pregnant woman in Cebu
# Chicago's First Zika Case Confirmed
# Tampa Bay Area Zika Case Count Climbs
# Bad Water Leads to Sickness in Flint, Michigan
# Baltimore plans for Zika virus
# ...

# %%
cols=["headline", "city", "country"]

# %%
import pandas as pd
headlines_df=pd.DataFrame(columns=cols)

# %%
headlines_df
# Out:
# Empty DataFrame
# Columns: [headline, city, country]
# Index: []

# %%
# !pip install geonamescache
# Out:
# ...
#      |████████████████████████████████| 839kB 2.8MB/s
# ...

# %%
import geonamescache

from geonamescache import GeonamesCache
gc = GeonamesCache()

# %%
cities = gc.get_cities()

# %%
cities
# Out:
# {'3041563': {'admin1code': '07',
#   'countrycode': 'AD',
#   'geonameid': 3041563,
#   'latitude': 42.50779,
#   'longitude': 1.52109,
#   'name': 'Andorra la Vella',
#   'population': 20430,
#   'timezone': 'Europe/Andorra'},
#  '290594': {'admin1code': '07',
#   'countrycode': 'AE',
#   'geonameid': 290594,
#   'latitude': 25.56473,
#   'longitude': 55.55517,
#   'name': 'Umm Al Quwain City',
#   'population': 62747,
#   'timezone': 'Asia/Dubai'},
#  '291074': {'admin1code': '05',
#   'countrycode': 'AE',
#   'geonameid': 291074,
#   'latitude': 25.78953,
#   'longitude': 55.9432,
#   'name': 'Ras Al Khaimah City',
#   'population': 351943,
#   'timezone': 'Asia/Dubai'},
#  '291580': {'admin1code': '01',
#   'countrycode': 'AE',
#   'geonameid': 291580,
#   'latitude': 23.65416,
#   'longitude': 53.70522,
#   'name': 'Zayed City',
#   'population': 63482,
#   'timezone': 'Asia/Dubai'},
#  '291696': {'admin1code': '06',
#   'countrycode': 'AE',
#   'geonameid': 291696,
# ...

# %%
countries = gc.get_countries()

# %%
countries
# Out:
# {'AD': {'areakm2': 468,
#   'capital': 'Andorra la Vella',
#   'continentcode': 'EU',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'fips': 'AN',
#   'geonameid': 3041565,
#   'iso': 'AD',
#   'iso3': 'AND',
#   'isonumeric': 20,
#   'languages': 'ca',
#   'name': 'Andorra',
#   'neighbours': 'ES,FR',
#   'phone': '376',
#   'population': 84000,
#   'postalcoderegex': '^(?:AD)*(\\d{3})$',
#   'tld': '.ad'},
#  'AE': {'areakm2': 82880,
#   'capital': 'Abu Dhabi',
#   'continentcode': 'AS',
#   'currencycode': 'AED',
#   'currencyname': 'Dirham',
#   'fips': 'AE',
#   'geonameid': 290557,
#   'iso': 'AE',
#   'iso3': 'ARE',
#   'isonumeric': 784,
#   'languages': 'ar-AE,fa,en,hi,ur',
#   'name': 'United Arab Emirates',
#   'neighbours': 'SA,OM',
#   'phone': '971',
#   'population': 4975593,
#   'postalcoderegex': '',
#   'tld': '.ae'},
#  'AF': {'areakm2': 647500,
#   'capital': 'Kabul',
#   'continentcode': 'AS',
#   'currencycode': 'AFN',
#   'currencyname': 'Afghani',
# ...

# %%
city_id = list(cities.keys())[0]
print(cities[city_id])
# Out:
# {'geonameid': 3041563, 'name': 'Andorra la Vella', 'latitude': 42.50779, 'longitude': 1.52109, 'countrycode': 'AD', 'population': 20430, 'timezone': 'Europe/Andorra', 'admin1code': '07'}

# %%
city_id
# Out:
# '3041563'

# %%
cities[city_id]
# Out:
# {'admin1code': '07',
#  'countrycode': 'AD',
#  'geonameid': 3041563,
#  'latitude': 42.50779,
#  'longitude': 1.52109,
#  'name': 'Andorra la Vella',
#  'population': 20430,
#  'timezone': 'Europe/Andorra'}

# %%
cities[city_id]['name']
# Out:
# 'Andorra la Vella'

# %%
cities_names=[]
cities_id=list(cities.keys())
for city_id in cities_id:
    cities_names.append(cities[city_id]['name'])

# %%
cities_names
# Out:
# ['Andorra la Vella',
#  'Umm Al Quwain City',
#  'Ras Al Khaimah City',
#  'Zayed City',
#  'Khawr Fakkān',
#  'Dubai',
#  'Dibba Al-Fujairah',
#  'Dibba Al-Hisn',
#  'Sharjah',
#  'Ar Ruways',
#  'Al Fujairah City',
#  'Al Ain City',
#  'Ajman City',
#  'Adh Dhayd',
#  'Abu Dhabi',
#  'Khalifah A City',
#  'Bani Yas City',
#  'Musaffah',
#  'Al Shamkhah City',
#  'Reef Al Fujairah City',
#  'Zaranj',
#  'Taloqan',
#  'Shīnḏanḏ',
#  'Shibirghān',
#  'Shahrak',
#  'Sar-e Pul',
#  'Sang-e Chārak',
#  'Aībak',
#  'Rustāq',
#  'Qarqīn',
#  'Qarāwul',
#  'Pul-e Khumrī',
#  'Paghmān',
#  'Nahrīn',
#  'Maymana',
#  'Mehtar Lām',
#  'Mazār-e Sharīf',
#  'Lashkar Gāh',
#  'Kushk',
#  'Kunduz',
#  'Khōst',
#  'Khulm',
#  'Khāsh',
#  'Khanabad',
#  'Karukh',
#  'Kandahār',
#  'Kabul',
#  'Jalālābād',
#  'Jabal os Saraj',
#  'Herāt',
#  'Ghormach',
#  'Ghazni',
#  'Gereshk',
#  'Gardez',
#  'Fayzabad',
#  'Farah',
#  'Kafir Qala',
#  'Charikar',
#  'Baraki Barak',
#  'Bāmyān',
#  'Balkh',
# ...

# %%
len(cities_names)
# Out:
# 24336

# %%
countries_names=[]
countries_id=list(countries.keys())
for country_id in countries_id:
    countries_names.append(countries[country_id]['name'])

# %%
countries_names
# Out:
# ['Andorra',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Antigua and Barbuda',
#  'Anguilla',
#  'Albania',
#  'Armenia',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'American Samoa',
#  'Austria',
#  'Australia',
#  'Aruba',
#  'Aland Islands',
#  'Azerbaijan',
#  'Bosnia and Herzegovina',
#  'Barbados',
#  'Bangladesh',
#  'Belgium',
#  'Burkina Faso',
#  'Bulgaria',
#  'Bahrain',
#  'Burundi',
#  'Benin',
#  'Saint Barthelemy',
#  'Bermuda',
#  'Brunei',
#  'Bolivia',
#  'Bonaire, Saint Eustatius and Saba ',
#  'Brazil',
#  'Bahamas',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Belarus',
#  'Belize',
#  'Canada',
#  'Cocos Islands',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Switzerland',
#  'Ivory Coast',
#  'Cook Islands',
#  'Chile',
#  'Cameroon',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Cabo Verde',
#  'Curacao',
#  'Christmas Island',
#  'Cyprus',
#  'Czechia',
#  'Germany',
# ...

# %%
# !pip install unidecode
from unidecode import unidecode
accented_names = [city['name'] for city in gc.get_cities().values()
                  if city['name'] != unidecode(city['name'])]
# Out:
# ...
#      |████████████████████████████████| 245kB 2.7MB/s
# ...

# %%
cities_names_unidecoded=[unidecode(city) for city in cities_names]

# %%
cities_names_unidecoded
# Out:
# ['Andorra la Vella',
#  'Umm Al Quwain City',
#  'Ras Al Khaimah City',
#  'Zayed City',
#  'Khawr Fakkan',
#  'Dubai',
#  'Dibba Al-Fujairah',
#  'Dibba Al-Hisn',
#  'Sharjah',
#  'Ar Ruways',
#  'Al Fujairah City',
#  'Al Ain City',
#  'Ajman City',
#  'Adh Dhayd',
#  'Abu Dhabi',
#  'Khalifah A City',
#  'Bani Yas City',
#  'Musaffah',
#  'Al Shamkhah City',
#  'Reef Al Fujairah City',
#  'Zaranj',
#  'Taloqan',
#  'Shindand',
#  'Shibirghan',
#  'Shahrak',
#  'Sar-e Pul',
#  'Sang-e Charak',
#  'Aibak',
#  'Rustaq',
#  'Qarqin',
#  'Qarawul',
#  'Pul-e Khumri',
#  'Paghman',
#  'Nahrin',
#  'Maymana',
#  'Mehtar Lam',
#  'Mazar-e Sharif',
#  'Lashkar Gah',
#  'Kushk',
#  'Kunduz',
#  'Khost',
#  'Khulm',
#  'Khash',
#  'Khanabad',
#  'Karukh',
#  'Kandahar',
#  'Kabul',
#  'Jalalabad',
#  'Jabal os Saraj',
#  'Herat',
#  'Ghormach',
#  'Ghazni',
#  'Gereshk',
#  'Gardez',
#  'Fayzabad',
#  'Farah',
#  'Kafir Qala',
#  'Charikar',
#  'Baraki Barak',
#  'Bamyan',
#  'Balkh',
# ...

# %%
len(cities_names)
# Out:
# 24336

# %%
cities_names[0]
# Out:
# 'Andorra la Vella'

# %%
countries_unidecoded=[unidecode(country) for country in countries_names]

# %%
countries_unidecoded
# Out:
# ['Andorra',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Antigua and Barbuda',
#  'Anguilla',
#  'Albania',
#  'Armenia',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'American Samoa',
#  'Austria',
#  'Australia',
#  'Aruba',
#  'Aland Islands',
#  'Azerbaijan',
#  'Bosnia and Herzegovina',
#  'Barbados',
#  'Bangladesh',
#  'Belgium',
#  'Burkina Faso',
#  'Bulgaria',
#  'Bahrain',
#  'Burundi',
#  'Benin',
#  'Saint Barthelemy',
#  'Bermuda',
#  'Brunei',
#  'Bolivia',
#  'Bonaire, Saint Eustatius and Saba ',
#  'Brazil',
#  'Bahamas',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Belarus',
#  'Belize',
#  'Canada',
#  'Cocos Islands',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Switzerland',
#  'Ivory Coast',
#  'Cook Islands',
#  'Chile',
#  'Cameroon',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Cabo Verde',
#  'Curacao',
#  'Christmas Island',
#  'Cyprus',
#  'Czechia',
#  'Germany',
# ...

# %%
countries_unidecoded_new=[]
for country in countries_unidecoded:
    if ',' in country:
        country=country.split(',')
        country_str = country[1] + country[0]
        new_country = ''.join(country_str)
        countries_unidecoded_new.append(new_country)
    else:
        countries_unidecoded_new.append(country)

# %%
countries_unidecoded_new
# Out:
# ['Andorra',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Antigua and Barbuda',
#  'Anguilla',
#  'Albania',
#  'Armenia',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'American Samoa',
#  'Austria',
#  'Australia',
#  'Aruba',
#  'Aland Islands',
#  'Azerbaijan',
#  'Bosnia and Herzegovina',
#  'Barbados',
#  'Bangladesh',
#  'Belgium',
#  'Burkina Faso',
#  'Bulgaria',
#  'Bahrain',
#  'Burundi',
#  'Benin',
#  'Saint Barthelemy',
#  'Bermuda',
#  'Brunei',
#  'Bolivia',
#  ' Saint Eustatius and Saba Bonaire',
#  'Brazil',
#  'Bahamas',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Belarus',
#  'Belize',
#  'Canada',
#  'Cocos Islands',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Switzerland',
#  'Ivory Coast',
#  'Cook Islands',
#  'Chile',
#  'Cameroon',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Cabo Verde',
#  'Curacao',
#  'Christmas Island',
#  'Cyprus',
#  'Czechia',
#  'Germany',
# ...

# %%
import numpy as np
import pandas as pd
import re

dict_city=dict()
dict_country=dict()
for city_name in cities_names_unidecoded:
    regexp_city_name = re.compile(r'\b'+city_name+r'\b')
    dict_city[city_name]= regexp_city_name
for country in countries_unidecoded_new:
    regexp_country_name=re.compile(r'\b'+country+r'\b')
    dict_country[country] =  regexp_country_name
    
    
for city_name in cities_names_unidecoded:
    for headline in maplist:
        if dict_city[city_name].search(headline):
            for country in countries_unidecoded_new:
                if dict_country[country].search(headline):
                    a_row = pd.Series([headline, city_name, country])
                    row_df = pd.DataFrame([a_row])
                    headlines_df = pd.concat([row_df, headlines_df], ignore_index=True)
                else:
                    a_row = pd.Series([headline, city_name, np.nan])
                    row_df = pd.DataFrame([a_row])
                    headlines_df = pd.concat([row_df, headlines_df], ignore_index=True)
        else:
            for country in countries_unidecoded_new:
                if dict_country[country].search(headline):
                    a_row = pd.Series([headline, np.nan, country])
                    row_df = pd.DataFrame([a_row])
                    headlines_df = pd.concat([row_df, headlines_df], ignore_index=True)
                else:
                    a_row = pd.Series([headline, np.nan, np.nan])
                    row_df = pd.DataFrame([a_row])
                    headlines_df = pd.concat([row_df, headlines_df], ignore_index=True)
        
print(headlines_df)
